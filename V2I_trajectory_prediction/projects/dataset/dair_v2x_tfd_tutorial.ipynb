# %% [markdown]
# ## Data loading

# %%
import sys
sys.path.append("../..") # set current execution dictionary to parent dictionary (main dictionary)

from projects.dataset.dair_data_loader import DAIRV2XDataLoader
from projects.dataset.dair_map_api import DAIRV2XMap

dvm = DAIRV2XMap()

# vic_dir = '../../dataset/v2x-seq-tfd/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/cooperative-trajectories/train/'
# car_dir = '../../dataset/v2x-seq-tfd/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/vehicle-trajectories/train/'
# road_dir = '../../dataset/v2x-seq-tfd/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/infrastructure-trajectories/train/'
# tl_dir = '../../dataset/v2x-seq-tfd/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/traffic-light/train/'

vic_dir = '/home/yc27979/mc451742/V2I_trajectory_prediction/V2X-Seq/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/cooperative-trajectories/train/data/'
car_dir = '/home/yc27979/mc451742/V2I_trajectory_prediction/V2X-Seq/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/vehicle-trajectories/train/data/'
road_dir = '/home/yc27979/mc451742/V2I_trajectory_prediction/V2X-Seq/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/infrastructure-trajectories/train/data/'
tl_dir = '/home/yc27979/mc451742/V2I_trajectory_prediction/V2X-Seq/V2X-Seq-TFD-Example/cooperative-vehicle-infrastructure/traffic-light/train/'

vic_dl = DAIRV2XDataLoader(vic_dir)
car_dl = DAIRV2XDataLoader(car_dir)
road_dl = DAIRV2XDataLoader(road_dir)
tl_dl = DAIRV2XDataLoader(tl_dir)

# %%
# read csv files
car_dl.seq_df
road_dl.seq_df
vic_dl.seq_df
tl_dl.seq_df
# Out:
#     city     timestamp              x             y direction        lane_id  \
# 0    PEK  1.662889e+09  417891.063152  4.731625e+06      EAST  23180456_1_-1
# 1    PEK  1.662889e+09  417854.013167  4.731640e+06      WEST  23179490_1_-1
# 2    PEK  1.662889e+09  417855.812252  4.731637e+06      WEST  23179445_1_-1
# 3    PEK  1.662889e+09  417850.944785  4.731676e+06     SOUTH  23180494_1_-1
# 4    PEK  1.662889e+09  417888.753341  4.731668e+06     NORTH  23179491_1_-1
# ..   ...           ...            ...           ...       ...            ...
# 529  PEK  1.662889e+09  417854.013167  4.731640e+06      WEST  23179490_1_-1
# 530  PEK  1.662889e+09  417855.812252  4.731637e+06      WEST  23179445_1_-1
# 531  PEK  1.662889e+09  417850.944785  4.731676e+06     SOUTH  23180494_1_-1
# 532  PEK  1.662889e+09  417888.753341  4.731668e+06     NORTH  23179491_1_-1
# 533  PEK  1.662889e+09  417886.971313  4.731671e+06     NORTH  23179447_1_-1
#
# ...

# %% [markdown]
# ## Visualizing sequences

# %%
import tools
from tools.visualize.tfd_visualize import viz_static

# %%
viz_static(car_dl.seq_df, show=True)
#viz_static(road_dl.seq_df, show=True)
